# %% [markdown]
# Importing useful Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading all CSV

# %%
Health_Camp_Detail = pd.read_csv('Health_Camp_Detail.csv')
Patient_Profile = pd.read_csv('Patient_Profile.csv')
First_Health_Camp_Attended = pd.read_csv('First_Health_Camp_Attended.csv')
Second_Health_Camp_Attended = pd.read_csv('Second_Health_Camp_Attended.csv')
Third_Health_Camp_Attended = pd.read_csv('Third_Health_Camp_Attended.csv')

# %%
Health_Camp_Detail
# Out:
#     Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  \
# 0             6560       16-Aug-03     20-Aug-03     First         B
# 1             6530       16-Aug-03     28-Oct-03     First         C
# 2             6544       03-Nov-03     15-Nov-03     First         F
# 3             6585       22-Nov-03     05-Dec-03     First         E
# 4             6561       30-Nov-03     18-Dec-03     First         E
# ..             ...             ...           ...       ...       ...
# 60            6556       09-Nov-06     15-Dec-06     First         E
# 61            6551       13-Nov-06     18-Nov-06    Second         D
# 62            6559       11-Dec-06     12-Mar-07     First         F
# 63            6567       30-Jan-07     04-Feb-07    Second         D
# 64            6577       30-Jan-07     08-Mar-07     Third         G
#
#     Category3
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1
# ..        ...
# 60          2
# ...

# %% [markdown]
# Getting all the information about the data

# %%
Health_Camp_Detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Health_Camp_ID   65 non-null     int64
#  1   Camp_Start_Date  65 non-null     object
#  2   Camp_End_Date    65 non-null     object
#  3   Category1        65 non-null     object
#  4   Category2        65 non-null     object
#  5   Category3        65 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 3.2+ KB

# %%
Health_Camp_Detail.describe(include='all')
# Out:
#         Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  \
# count         65.00000              65            65        65        65
# unique             NaN              58            54         3         7
# top                NaN       16-Aug-03     07-Nov-07     First         C
# freq               NaN               2             5        44        16
# mean        6555.00000             NaN           NaN       NaN       NaN
# std           18.90767             NaN           NaN       NaN       NaN
# min         6523.00000             NaN           NaN       NaN       NaN
# 25%         6539.00000             NaN           NaN       NaN       NaN
# 50%         6555.00000             NaN           NaN       NaN       NaN
# 75%         6571.00000             NaN           NaN       NaN       NaN
# max         6587.00000             NaN           NaN       NaN       NaN
#
#         Category3
# count   65.000000
# unique        NaN
# top           NaN
# ...

# %%
#first 10 rows of Health_Camp_Detail


Health_Camp_Detail.head(10)
# Out:
#    Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  Category3
# 0            6560       16-Aug-03     20-Aug-03     First         B          2
# 1            6530       16-Aug-03     28-Oct-03     First         C          2
# 2            6544       03-Nov-03     15-Nov-03     First         F          1
# 3            6585       22-Nov-03     05-Dec-03     First         E          2
# 4            6561       30-Nov-03     18-Dec-03     First         E          1
# 5            6581       07-Dec-03     13-Jun-04     First         F          2
# 6            6564       17-Dec-03     11-Jun-04     First         C          2
# 7            6557       04-Jan-04     09-Jan-04     First         C          2
# 8            6538       09-Jan-04     04-Feb-05     First         F          2
# 9            6546       09-Jan-04     17-Jan-04     First         E          2

# %%
Health_Camp_Detail.count()
# Out:
# Health_Camp_ID     65
# Camp_Start_Date    65
# Camp_End_Date      65
# Category1          65
# Category2          65
# Category3          65
# dtype: int64

# %%
Health_Camp_Detail.value_counts()
# Out:
# Health_Camp_ID  Camp_Start_Date  Camp_End_Date  Category1  Category2  Category3
# 6523            23-Feb-05        16-Sep-05      Second     D          2            1
# 6556            09-Nov-06        15-Dec-06      First      E          2            1
# 6558            22-Aug-04        27-Aug-04      First      C          2            1
# 6559            11-Dec-06        12-Mar-07      First      F          2            1
# 6560            16-Aug-03        20-Aug-03      First      B          2            1
#                                                                                   ..
# 6550            12-Oct-06        18-Dec-06      Third      G          2            1
# 6551            13-Nov-06        18-Nov-06      Second     D          2            1
# 6552            21-May-04        24-May-04      First      C          2            1
# 6553            26-Apr-04        04-May-04      First      C          2            1
# ...

# %%
Health_Camp_Detail.index
# Out:
# RangeIndex(start=0, stop=65, step=1)

# %%
Health_Camp_Detail.dtypes
# Out:
# Health_Camp_ID      int64
# Camp_Start_Date    object
# Camp_End_Date      object
# Category1          object
# Category2          object
# Category3           int64
# dtype: object

# %%
Health_Camp_Detail.nunique()
# Out:
# Health_Camp_ID     65
# Camp_Start_Date    58
# Camp_End_Date      54
# Category1           3
# Category2           7
# Category3           2
# dtype: int64

# %%
Health_Camp_Detail.shape
# Out:
# (65, 6)

# %%
Health_Camp_Detail.isnull()
# Out:
#     Health_Camp_ID  Camp_Start_Date  Camp_End_Date  Category1  Category2  \
# 0            False            False          False      False      False
# 1            False            False          False      False      False
# 2            False            False          False      False      False
# 3            False            False          False      False      False
# 4            False            False          False      False      False
# ..             ...              ...            ...        ...        ...
# 60           False            False          False      False      False
# 61           False            False          False      False      False
# 62           False            False          False      False      False
# 63           False            False          False      False      False
# 64           False            False          False      False      False
#
#     Category3
# 0       False
# 1       False
# 2       False
# 3       False
# ...

# %%
Health_Camp_Detail.isnull().sum()
# Out:
# Health_Camp_ID     0
# Camp_Start_Date    0
# Camp_End_Date      0
# Category1          0
# Category2          0
# Category3          0
# dtype: int64

# %%
Health_Camp_Detail.duplicated().sum()
# Out:
# 0

# %% [markdown]
# as there are no null values and duplicated values now changing the format of Camp_Start_Date and Camp_End_Date from object to dateTime format

# %%
import datetime
Health_Camp_Detail['Camp_Start_Date']=pd.to_datetime(Health_Camp_Detail['Camp_Start_Date'])
Health_Camp_Detail['Camp_End_Date']=pd.to_datetime(Health_Camp_Detail['Camp_End_Date'])

# %%
Health_Camp_Detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Health_Camp_ID   65 non-null     int64
#  1   Camp_Start_Date  65 non-null     datetime64[ns]
#  2   Camp_End_Date    65 non-null     datetime64[ns]
#  3   Category1        65 non-null     object
#  4   Category2        65 non-null     object
#  5   Category3        65 non-null     int64
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 3.2+ KB

# %%
Health_Camp_Detail['Health_Camp_ID'].value_counts()
# Out:
# 6560    1
# 6587    1
# 6555    1
# 6543    1
# 6537    1
#        ..
# 6523    1
# 6524    1
# 6527    1
# 6554    1
# 6577    1
# Name: Health_Camp_ID, Length: 65, dtype: int64

# %% [markdown]
# Creating new columns of month quarter and duration of Health Camp

# %%
#Camp_Start_Date
Health_Camp_Detail['Camp_Start_Month']=Health_Camp_Detail['Camp_Start_Date'].apply(lambda x:x.month)
Health_Camp_Detail['Camp_Start_Day']=Health_Camp_Detail['Camp_Start_Date'].apply(lambda x:x.day)
Health_Camp_Detail['Camp_Start_Quarter']=Health_Camp_Detail['Camp_Start_Date'].apply(lambda x:x.quarter)

#Camp_End_Date
Health_Camp_Detail['Camp_End_Month']=Health_Camp_Detail['Camp_End_Date'].apply(lambda x:x.month)
Health_Camp_Detail['Camp_End_Day']=Health_Camp_Detail['Camp_End_Date'].apply(lambda x:x.day)
Health_Camp_Detail['Camp_End_Quarter']=Health_Camp_Detail['Camp_End_Date'].apply(lambda x:x.quarter)

#Camp_Duration
Health_Camp_Detail['Camp_Duration']=(Health_Camp_Detail['Camp_End_Date']-Health_Camp_Detail['Camp_Start_Date']).astype('timedelta64[D]')

# %%
Health_Camp_Detail
# Out:
#     Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  \
# 0             6560      2003-08-16    2003-08-20     First         B
# 1             6530      2003-08-16    2003-10-28     First         C
# 2             6544      2003-11-03    2003-11-15     First         F
# 3             6585      2003-11-22    2003-12-05     First         E
# 4             6561      2003-11-30    2003-12-18     First         E
# ..             ...             ...           ...       ...       ...
# 60            6556      2006-11-09    2006-12-15     First         E
# 61            6551      2006-11-13    2006-11-18    Second         D
# 62            6559      2006-12-11    2007-03-12     First         F
# 63            6567      2007-01-30    2007-02-04    Second         D
# 64            6577      2007-01-30    2007-03-08     Third         G
#
#     Category3  Camp_Start_Month  Camp_Start_Day  Camp_Start_Quarter  \
# 0           2                 8              16                   3
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# -Number of camps started in each month.

# %%
Health_Camp_Detail['Camp_Start_Quarter'].value_counts()
# Out:
# 3    20
# 4    19
# 1    13
# 2    13
# Name: Camp_Start_Quarter, dtype: int64

# %%
sns.countplot(Health_Camp_Detail['Camp_Start_Quarter'])
plt.title('Camps starting in each Quarter')
# Out:
# Text(0.5, 1.0, 'Camps starting in each Quarter')

# %% [markdown]
# -Number of camps ended in each month.

# %%
Health_Camp_Detail.Camp_End_Quarter.value_counts()
# Out:
# 3    21
# 4    18
# 2    13
# 1    13
# Name: Camp_End_Quarter, dtype: int64

# %%
sns.countplot(Health_Camp_Detail.Camp_End_Quarter)
plt.title('Camps ending in each Quarter')
# Out:
# Text(0.5, 1.0, 'Camps ending in each Quarter')

# %% [markdown]
# -- As we saw that highest number of camps were started and ended in 3rd quarter and lowest number of camps started and ended were in both 1st and 2nd quarter

# %% [markdown]
# Monthly analysis

# %% [markdown]
# Number of Camps started in each month

# %%
Health_Camp_Detail.Camp_Start_Month.value_counts()
# Out:
# 8     10
# 11     8
# 9      8
# 12     6
# 1      6
# 2      6
# 4      6
# 10     5
# 6      4
# 5      3
# 7      2
# 3      1
# Name: Camp_Start_Month, dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.countplot(Health_Camp_Detail.Camp_Start_Month)
plt.title('Camps started in each month')
# Out:
# Text(0.5, 1.0, 'Camps started in each month')

# %% [markdown]
# -Number of Camps ended in each month

# %%
Health_Camp_Detail.Camp_End_Month.value_counts()
# Out:
# 8     9
# 11    8
# 9     8
# 2     6
# 10    5
# 12    5
# 4     5
# 6     4
# 1     4
# 5     4
# 7     4
# 3     3
# Name: Camp_End_Month, dtype: int64

# %%
plt.figure(figsize=(7,3))
sns.countplot(Health_Camp_Detail.Camp_End_Month)
plt.title('Camps ended in each month')
# Out:
# Text(0.5, 1.0, 'Camps ended in each month')

# %% [markdown]
# ---- As we saw that highest number of camps were started and ended in 8th month and lowest number of camps started and ended were in 3rd month.

# %% [markdown]
# Camp Duration analysis

# %% [markdown]
# first we will check for outliers

# %%
sns.boxplot(Health_Camp_Detail.Camp_Duration)
# Out:
# <AxesSubplot:xlabel='Camp_Duration'>

# %% [markdown]
# As we can see there are outliers. We will remove them for better accuracy.

# %%
q1 , q3 = Health_Camp_Detail.Camp_Duration.quantile([0.25,0.75])
print(q1 , q3)
# Out:
# 5.0 74.0

# %%
iqr = q3 - q1
print(iqr)
# Out:
# 69.0

# %%
ll = q1 - 1.5*(iqr)
ul = q3 + 1.5*(iqr)
print (ll,ul)
# Out:
# -98.5 177.5

# %%
Health_Camp_Detail[Health_Camp_Detail.Camp_Duration>ul]
# Out:
#     Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  \
# 5             6581      2003-12-07    2004-06-13     First         F
# 8             6538      2004-01-09    2005-02-04     First         F
# 14            6539      2004-08-07    2005-02-12     First         F
# 20            6562      2004-11-24    2005-06-02     First         F
# 25            6542      2005-02-19    2005-08-23     First         F
# 26            6532      2005-02-19    2005-08-23     First         F
# 27            6523      2005-02-23    2005-09-16    Second         D
# 36            6543      2005-09-27    2007-11-07     First         F
# 37            6537      2005-09-27    2007-11-07     First         F
# 40            6534      2005-10-17    2007-11-07    Second         A
# 45            6582      2006-04-06    2007-11-07     First         F
# 54            6576      2006-08-19    2007-11-07     Third         G
#
# ...

# %%
len(Health_Camp_Detail[Health_Camp_Detail.Camp_Duration>ul])
# Out:
# 12

# %%
Health_Camp_Detail.Camp_Duration=np.where(Health_Camp_Detail['Camp_Duration']>ul,ul,Health_Camp_Detail.Camp_Duration)

# %%
sns.boxplot(Health_Camp_Detail.Camp_Duration)
# Out:
# <AxesSubplot:xlabel='Camp_Duration'>

# %%
sns.displot(x=Health_Camp_Detail.Camp_Duration , data=Health_Camp_Detail , kde=True)
plt.ylabel('No of camps')
plt.title('Camps Duration Distribution')
# Out:
# Text(0.5, 1.0, 'Camps Duration Distribution')

# %% [markdown]
# we can clearly see that duration of most number of camps was between 0 to 25 days.

# %%
Patient_Profile
# Out:
#        Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0          516956                0                0               0
# 1          507733                0                0               0
# 2          508307                0                0               0
# 3          512612                0                0               0
# 4          521075                0                0               0
# ...           ...              ...              ...             ...
# 37628      518600                0                0               0
# 37629      509515                0                0               0
# 37630      510713                0                0               0
# 37631      493667                0                0               0
# 37632      498051                0                0               0
#
#        Facebook_Shared Income Education_Score   Age First_Interaction  \
# 0                    0      1              90    39         18-Jun-03
# ...

# %% [markdown]
# Checking data distribution of social media platforms.

# %%
Patient_Profile.Online_Follower.value_counts()
# Out:
# 0    36785
# 1      848
# Name: Online_Follower, dtype: int64

# %%
Patient_Profile.LinkedIn_Shared.value_counts()
# Out:
# 0    36614
# 1     1019
# Name: LinkedIn_Shared, dtype: int64

# %%
Patient_Profile.Twitter_Shared.value_counts()
# Out:
# 0    36820
# 1      813
# Name: Twitter_Shared, dtype: int64

# %%
Patient_Profile.Facebook_Shared.value_counts()
# Out:
# 0    36747
# 1      886
# Name: Facebook_Shared, dtype: int64

# %%
Patient_Profile.drop(['Online_Follower','LinkedIn_Shared','Twitter_Shared','Facebook_Shared'],axis = 1)
# Out:
#        Patient_ID Income Education_Score   Age First_Interaction City_Type  \
# 0          516956      1              90    39         18-Jun-03       NaN
# 1          507733      1            None    40         20-Jul-03         H
# 2          508307      3              87    46         02-Nov-02         D
# 3          512612      1              75    47         02-Nov-02         D
# 4          521075      3            None    80         24-Nov-02         H
# ...           ...    ...             ...   ...               ...       ...
# 37628      518600   None            None  None         28-Jan-07       NaN
# 37629      509515   None            None  None         27-Jan-07       NaN
# 37630      510713   None            None  None         01-Feb-07         H
# 37631      493667   None            None  None         27-Jan-07       NaN
# 37632      498051   None            None  None         29-Jan-07       NaN
#
#        Employer_Category
# 0      Software Industry
# ...

# %% [markdown]
# -analyzing the city type column

# %%
Patient_Profile.City_Type.describe()
# Out:
# count     14249
# unique        9
# top           B
# freq       2662
# Name: City_Type, dtype: object

# %%
Patient_Profile.City_Type.value_counts().sort_values()
# Out:
# F     816
# I    1036
# C    1216
# E    1217
# G    1352
# D    1704
# A    1729
# H    2517
# B    2662
# Name: City_Type, dtype: int64

# %%
sns.countplot(Patient_Profile.City_Type.sort_values())
# Out:
# <AxesSubplot:xlabel='City_Type', ylabel='count'>

# %% [markdown]
# we can see that maximum number of Patients are from City-B and minimum number of Patients are from City-F

# %% [markdown]
# *Analyzing First_Health_Camp_Attended

# %%
First_Health_Camp_Attended
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score  Unnamed: 4
# 0         506181            6560        40      0.439024         NaN
# 1         494977            6560        20      0.097561         NaN
# 2         518680            6560        10      0.048780         NaN
# 3         509916            6560        30      0.634146         NaN
# 4         488006            6560        20      0.024390         NaN
# ...          ...             ...       ...           ...         ...
# 6213      502728            6575        10      0.509804         NaN
# 6214      511088            6575        20      0.078431         NaN
# 6215      507608            6575        40      0.627451         NaN
# 6216      488046            6575        50      0.686275         NaN
# 6217      508766            6575        50      0.921569         NaN
#
# [6218 rows x 5 columns]

# %%
First_Health_Camp_Attended.drop('Unnamed: 4',axis=1,inplace=True)

# %%
First_Health_Camp_Attended
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score
# 0         506181            6560        40      0.439024
# 1         494977            6560        20      0.097561
# 2         518680            6560        10      0.048780
# 3         509916            6560        30      0.634146
# 4         488006            6560        20      0.024390
# ...          ...             ...       ...           ...
# 6213      502728            6575        10      0.509804
# 6214      511088            6575        20      0.078431
# 6215      507608            6575        40      0.627451
# 6216      488046            6575        50      0.686275
# 6217      508766            6575        50      0.921569
#
# [6218 rows x 4 columns]

# %%
First_Health_Camp_Attended.describe()
# Out:
#           Patient_ID  Health_Camp_ID     Donation  Health_Score
# count    6218.000000     6218.000000  6218.000000   6218.000000
# mean   506929.053715     6552.904149    32.587649      0.517668
# std     12437.711002       19.095027    24.501676      0.289211
# min    485702.000000     6524.000000    10.000000      0.001667
# 25%    496069.000000     6538.000000    20.000000      0.263094
# 50%    506704.000000     6543.000000    30.000000      0.529706
# 75%    517747.750000     6570.000000    40.000000      0.771429
# max    528657.000000     6587.000000   330.000000      1.000000

# %%
First_Health_Camp_Attended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6218 entries, 0 to 6217
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      6218 non-null   int64
#  1   Health_Camp_ID  6218 non-null   int64
#  2   Donation        6218 non-null   int64
#  3   Health_Score    6218 non-null   float64
# dtypes: float64(1), int64(3)
# memory usage: 194.4 KB

# %%
First_Health_Camp_Attended.isnull().sum()
# Out:
# Patient_ID        0
# Health_Camp_ID    0
# Donation          0
# Health_Score      0
# dtype: int64

# %%
First_Health_Camp_Attended.Donation.nunique()
# Out:
# 24

# %%
sns.boxplot(First_Health_Camp_Attended.Donation)
# Out:
# <AxesSubplot:xlabel='Donation'>

# %%
Q1 , Q3 = First_Health_Camp_Attended.Donation.quantile([0.25,0.75])
print(Q1,Q3)
# Out:
# 20.0 40.0

# %%
Iqr= Q3-Q1
Ll= Q1-1.5*(Iqr)
Ul= Q3 + 1.5*(Iqr)
print(Ll,Ul)
# Out:
# -10.0 70.0

# %%
First_Health_Camp_Attended[First_Health_Camp_Attended['Donation']>Ul]
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score
# 68        503827            6585       110      0.783251
# 71        494076            6585       130      0.665025
# 80        502421            6585        80      0.714286
# 83        523092            6585        80      0.674877
# 90        487663            6585        80      0.561576
# ...          ...             ...       ...           ...
# 6029      493135            6537       160      0.997925
# 6033      491426            6537        80      0.912863
# 6049      500155            6537        90      0.950207
# 6053      516432            6537       130      0.987552
# 6128      507521            6537       100      0.705394
#
# [333 rows x 4 columns]

# %% [markdown]
# we have 333 outliers in this data and we will remove it with median this time.

# %%
First_Health_Camp_Attended['Donation']=np.where(First_Health_Camp_Attended['Donation']>Ul,First_Health_Camp_Attended.Donation.median(),First_Health_Camp_Attended.Donation)

# %%
sns.boxplot(First_Health_Camp_Attended.Donation)
# Out:
# <AxesSubplot:xlabel='Donation'>

# %%
px.bar(First_Health_Camp_Attended.Donation.value_counts())
# Out:
# <div>                            <div id="00cdc91f-1d8d-423a-b6e8-93ad1ff898ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00cdc91f-1d8d-423a-b6e8-93ad1ff898ce")) {                    Plotly.newPlot(                        "00cdc91f-1d8d-423a-b6e8-93ad1ff898ce",                        [{"alignmentgroup":"True","hovertemplate":"variable=Donation<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Donation","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Donation","offsetgroup":"Donation","orientation":"v","showlegend":true,"textposition":"auto","x":[20.0,30.0,10.0,40.0,50.0,60.0,70.0],"xaxis":"x","y":[1609,1583,1316,760,473,283,194],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{
# ...

# %% [markdown]
# we can see the highest number of donation is 20 amount and lowest number of donation is 70 amount.

# %% [markdown]
# now checking for outliers in health score column.

# %%
sns.boxplot(First_Health_Camp_Attended.Health_Score)
# Out:
# <AxesSubplot:xlabel='Health_Score'>

# %%
First_Health_Camp_Attended.Health_Score.value_counts()
# Out:
# 0.360339    111
# 0.464856    102
# 0.559855    101
# 0.753325     91
# 0.752137     58
#            ...
# 0.592058      1
# 0.469314      1
# 0.606498      1
# 0.812274      1
# 0.921569      1
# Name: Health_Score, Length: 3826, dtype: int64

# %%
px.histogram(First_Health_Camp_Attended.Health_Score)
# Out:
# <div>                            <div id="f64674fc-8ff3-42ec-8af3-14d9c8001231" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f64674fc-8ff3-42ec-8af3-14d9c8001231")) {                    Plotly.newPlot(                        "f64674fc-8ff3-42ec-8af3-14d9c8001231",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=Health_Score<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Health_Score","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Health_Score","offsetgroup":"Health_Score","orientation":"v","showlegend":true,"x":[0.43902439,0.097560976,0.048780488,0.634146341,0.024390244,0.658536585,0.536585366,0.12195122,0.463414634,0.87804878,0.585365854,0.707317073,0.926829268,0.073170732,0.7560
# ...

# %% [markdown]
# we can see that most of patients have health score ranging between 0.75-0.7699 and least number of patients have their health score range between 0.01-0.00999.

# %% [markdown]
# *Analyzing second Health Camp attended

# %%
Second_Health_Camp_Attended
# Out:
#       Patient_ID  Health_Camp_ID  Health Score
# 0         526631            6536      0.875136
# 1         509122            6536      0.755700
# 2         498864            6536      0.673181
# 3         515398            6536      0.722041
# 4         504624            6536      0.464712
# ...          ...             ...           ...
# 7814      490853            6529      0.103136
# 7815      499836            6529      0.507841
# 7816      511286            6529      0.627865
# 7817      522935            6529      0.252714
# 7818      489487            6529      0.691194
#
# [7819 rows x 3 columns]

# %%
Second_Health_Camp_Attended.describe()
# Out:
#           Patient_ID  Health_Camp_ID  Health Score
# count    7819.000000     7819.000000   7819.000000
# mean   507184.188004     6534.044891      0.554178
# std     12358.248560        9.135749      0.249378
# min    485682.000000     6523.000000      0.058993
# 25%    496537.500000     6529.000000      0.389626
# 50%    507078.000000     6534.000000      0.518797
# 75%    517805.500000     6536.000000      0.762724
# max    528657.000000     6555.000000      1.000000

# %%
Second_Health_Camp_Attended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7819 entries, 0 to 7818
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      7819 non-null   int64
#  1   Health_Camp_ID  7819 non-null   int64
#  2   Health Score    7819 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 183.4 KB

# %%
Second_Health_Camp_Attended.isnull().sum()
# Out:
# Patient_ID        0
# Health_Camp_ID    0
# Health Score      0
# dtype: int64

# %%
sns.boxplot(Second_Health_Camp_Attended['Health Score'])
# Out:
# <AxesSubplot:xlabel='Health Score'>

# %%
px.histogram(x=Second_Health_Camp_Attended['Health Score'])
# Out:
# <div>                            <div id="ecd9eb3e-98e1-4761-981c-cdf923229ecc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ecd9eb3e-98e1-4761-981c-cdf923229ecc")) {                    Plotly.newPlot(                        "ecd9eb3e-98e1-4761-981c-cdf923229ecc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"x=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.875135722,0.755700326,0.673181325,0.72204126,0.464712269,0.587404995,0.72204126,0.825190011,0.963083605,0.755700326,0.72204126,0.897937025,0.52660152,0.159609121,0.755700326,0.72204126,0.241042345,0.499457112,0.825190011,0.825190011,
# ...

# %% [markdown]
# we can see that most of patients have health score ranging between 0.39-0.40999 and least number of patients have their health score range between 0.07-0.08999.

# %% [markdown]
# *Analyzing the third Health Camp attended

# %%
Third_Health_Camp_Attended
# Out:
#       Patient_ID  Health_Camp_ID  Number_of_stall_visited  \
# 0         517875            6527                        3
# 1         504692            6578                        1
# 2         504692            6527                        3
# 3         493167            6527                        4
# 4         510954            6528                        2
# ...          ...             ...                      ...
# 6510      503791            6527                        3
# 6511      517319            6528                        1
# 6512      517319            6578                        4
# 6513      517319            6527                        4
# 6514      511234            6527                        5
#
#       Last_Stall_Visited_Number
# 0                             1
# 1                             1
# 2                             1
# 3                             4
# 4                             2
# ...                         ...
# 6510                          3
# ...

# %%
Third_Health_Camp_Attended.describe()
# Out:
#           Patient_ID  Health_Camp_ID  Number_of_stall_visited  \
# count    6515.000000     6515.000000              6515.000000
# mean   506982.062011     6543.653415                 2.923254
# std     12489.080729       22.105649                 1.688500
# min    485679.000000     6527.000000                 0.000000
# 25%    496100.000000     6527.000000                 1.000000
# 50%    506825.000000     6528.000000                 3.000000
# 75%    517793.500000     6578.000000                 4.000000
# max    528656.000000     6578.000000                 7.000000
#
#        Last_Stall_Visited_Number
# count                6515.000000
# mean                    2.404144
# std                     1.469623
# min                     0.000000
# 25%                     1.000000
# 50%                     2.000000
# 75%                     3.000000
# max                     7.000000

# %%
Third_Health_Camp_Attended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6515 entries, 0 to 6514
# Data columns (total 4 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient_ID                 6515 non-null   int64
#  1   Health_Camp_ID             6515 non-null   int64
#  2   Number_of_stall_visited    6515 non-null   int64
#  3   Last_Stall_Visited_Number  6515 non-null   int64
# dtypes: int64(4)
# memory usage: 203.7 KB

# %%
Third_Health_Camp_Attended.isnull().sum()
# Out:
# Patient_ID                   0
# Health_Camp_ID               0
# Number_of_stall_visited      0
# Last_Stall_Visited_Number    0
# dtype: int64

# %%
Third_Health_Camp_Attended.Number_of_stall_visited.value_counts()
# Out:
# 1    1822
# 2    1243
# 3    1145
# 5    1034
# 4     701
# 6     536
# 0      18
# 7      16
# Name: Number_of_stall_visited, dtype: int64

# %%
sns.countplot(Third_Health_Camp_Attended.Number_of_stall_visited)
# Out:
# <AxesSubplot:xlabel='Number_of_stall_visited', ylabel='count'>

# %% [markdown]
# we can see that most of the paitents visited atleast one stall and least number of paitents visited 7 stalls.

# %%
Third_Health_Camp_Attended.Last_Stall_Visited_Number.value_counts()
# Out:
# 1    2497
# 2    1290
# 3    1234
# 4     753
# 5     472
# 6     245
# 0      18
# 7       6
# Name: Last_Stall_Visited_Number, dtype: int64

# %%
sns.countplot(Third_Health_Camp_Attended.Last_Stall_Visited_Number)
# Out:
# <AxesSubplot:xlabel='Last_Stall_Visited_Number', ylabel='count'>
